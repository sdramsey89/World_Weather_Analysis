# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy 

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | linhares
# Processing Record 5 of Set 1 | ballina
# Processing Record 6 of Set 1 | nassau
# Processing Record 7 of Set 1 | broome
# Processing Record 8 of Set 1 | faya
# Processing Record 9 of Set 1 | yulara
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | rosario
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | carauari
# Processing Record 16 of Set 1 | dolinsk
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | yerbogachen
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | albion
# Processing Record 26 of Set 1 | muros
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | caiaponia
# Processing Record 32 of Set 1 | siyabuswa
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | champerico
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | ginir
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | qeshm
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | namibe
# Processing Record 46 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 1 | riyadh
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | fort nelson
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | ocos
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | tourlaville
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | komsomolskiy
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | kargasok
# Processing Record 10 of Set 2 | gat
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | shingu
# Processing Record 14 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 2 | jogindarnagar
# Processing Record 16 of Set 2 | liaozhong
# Processing Record 17 of Set 2 | nishihara
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | sinnamary
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | pangody
# Processing Record 25 of Set 2 | lompoc
# Processing Record 26 of Set 2 | ayagoz
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | tual
# Processing Record 29 of Set 2 | mega
# Processing Record 30 of Set 2 | daltenganj
# Processing Record 31 of Set 2 | banjar
# Processing Record 32 of Set 2 | moerai
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | balfour
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | kawalu
# Processing Record 37 of Set 2 | vao
# Processing Record 38 of Set 2 | kenora
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | kutum
# Processing Record 41 of Set 2 | axim
# Processing Record 42 of Set 2 | lages
# Processing Record 43 of Set 2 | sioux lookout
# Processing Record 44 of Set 2 | porto novo
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | yaroslavl
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | ghansor
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | cedar falls
# Processing Record 5 of Set 3 | adrar
# Processing Record 6 of Set 3 | marsa matruh
# Processing Record 7 of Set 3 | hanting
# Processing Record 8 of Set 3 | fremont
# Processing Record 9 of Set 3 | luangwa
# Processing Record 10 of Set 3 | cockburn town
# Processing Record 11 of Set 3 | baglung
# Processing Record 12 of Set 3 | makakilo city
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | yelbarga
# Processing Record 18 of Set 3 | middle valley
# Processing Record 19 of Set 3 | launceston
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | griffith
# Processing Record 24 of Set 3 | cognac
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | hare bay
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | ambunti
# Processing Record 33 of Set 3 | saint anthony
# Processing Record 34 of Set 3 | upata
# Processing Record 35 of Set 3 | bakhmach
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | bambanglipuro
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | mastic beach
# Processing Record 42 of Set 3 | kailua
# Processing Record 43 of Set 3 | saint-joseph
# Processing Record 44 of Set 3 | dongying
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | pahrump
# Processing Record 47 of Set 3 | diego de almagro
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 50 of Set 3 | saint-georges
# Processing Record 1 of Set 4 | cairns
# Processing Record 2 of Set 4 | albacete
# Processing Record 3 of Set 4 | paamiut
# Processing Record 4 of Set 4 | mezocsat
# Processing Record 5 of Set 4 | lata
# Processing Record 6 of Set 4 | santa maria
# Processing Record 7 of Set 4 | boa vista
# Processing Record 8 of Set 4 | bilibino
# Processing Record 9 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | tiksi
# Processing Record 12 of Set 4 | tecoanapa
# Processing Record 13 of Set 4 | savannah bight
# Processing Record 14 of Set 4 | sola
# Processing Record 15 of Set 4 | olinda
# Processing Record 16 of Set 4 | alexandria
# Processing Record 17 of Set 4 | ondjiva
# Processing Record 18 of Set 4 | mandera
# Processing Record 19 of Set 4 | erenhot
# Processing Record 20 of Set 4 | lamu
# Processing Record 21 of Set 4 | urusha
# Processing Record 22 of Set 4 | akron
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | the valley
# Processing Record 26 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | neryungri
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | newport
# Processing Record 32 of Set 4 | bud
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | madang
# Processing Record 35 of Set 4 | destin
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | saint-leu
# Processing Record 38 of Set 4 | la primavera
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | iquitos
# Processing Record 41 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 42 of Set 4 | techiman
# Processing Record 43 of Set 4 | vanimo
# Processing Record 44 of Set 4 | suntar
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | port alfred
# Processing Record 47 of Set 4 | bom jesus
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | bara
# Processing Record 50 of Set 4 | safakulevo
# Processing Record 1 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | mahibadhoo
# Processing Record 4 of Set 5 | qaanaaq
# Processing Record 5 of Set 5 | magdagachi
# Processing Record 6 of Set 5 | beringovskiy
# Processing Record 7 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | paragominas
# Processing Record 10 of Set 5 | shelburne
# Processing Record 11 of Set 5 | devin
# Processing Record 12 of Set 5 | waverly
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | klaksvik
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | presidencia roque saenz pena
# Processing Record 17 of Set 5 | pangkalanbuun
# Processing Record 18 of Set 5 | la ronge
# Processing Record 19 of Set 5 | cabedelo
# Processing Record 20 of Set 5 | amapa
# Processing Record 21 of Set 5 | sao joao da barra
# Processing Record 22 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 5 | tacuarembo
# Processing Record 24 of Set 5 | asau
# Processing Record 25 of Set 5 | arman
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | hami
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | maniitsoq
# Processing Record 30 of Set 5 | peleduy
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | saldanha
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | butaritari
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | westport
# Processing Record 39 of Set 5 | timmins
# Processing Record 40 of Set 5 | rozivka
# Processing Record 41 of Set 5 | margate
# Processing Record 42 of Set 5 | dzhebariki-khaya
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | urucui
# Processing Record 45 of Set 5 | rio gallegos
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | henties bay
# Processing Record 48 of Set 5 | at-bashi
# Processing Record 49 of Set 5 | podyuga
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | saskylakh
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | redcliffe
# Processing Record 4 of Set 6 | ipixuna
# Processing Record 5 of Set 6 | nara
# Processing Record 6 of Set 6 | erzin
# Processing Record 7 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 6 | charkhi dadri
# Processing Record 9 of Set 6 | aswan
# Processing Record 10 of Set 6 | eagle pass
# Processing Record 11 of Set 6 | hervey bay
# Processing Record 12 of Set 6 | santiago del estero
# Processing Record 13 of Set 6 | port elizabeth
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | zemio
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | tshikapa
# Processing Record 20 of Set 6 | longhua
# Processing Record 21 of Set 6 | antalaha
# Processing Record 22 of Set 6 | kamina
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 6 | koungou
# Processing Record 27 of Set 6 | awjilah
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 6 | verkhnevilyuysk
# Processing Record 31 of Set 6 | valparaiso
# Processing Record 32 of Set 6 | kiunga
# Processing Record 33 of Set 6 | qaqortoq
# Processing Record 34 of Set 6 | corinto
# Processing Record 35 of Set 6 | takoradi
# Processing Record 36 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 6 | yabrud
# Processing Record 38 of Set 6 | broken hill
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | divnomorskoye
# Processing Record 41 of Set 6 | ust-nera
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | laguna
# Processing Record 45 of Set 6 | moroni
# Processing Record 46 of Set 6 | nuuk
# Processing Record 47 of Set 6 | patea
# Processing Record 48 of Set 6 | vrsac
# Processing Record 49 of Set 6 | whitehorse
# Processing Record 50 of Set 6 | ojhar
# Processing Record 1 of Set 7 | pafos
# Processing Record 2 of Set 7 | misawa
# Processing Record 3 of Set 7 | pyapon
# Processing Record 4 of Set 7 | verkhnyaya toyma
# Processing Record 5 of Set 7 | ponta do sol
# Processing Record 6 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 7 | okhotsk
# Processing Record 8 of Set 7 | erdenet
# Processing Record 9 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 7 | loyga
# Processing Record 11 of Set 7 | biscarrosse
# Processing Record 12 of Set 7 | kamensk-uralskiy
# Processing Record 13 of Set 7 | fort wellington
# Processing Record 14 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 15 of Set 7 | ribeira grande
# Processing Record 16 of Set 7 | port hedland
# Processing Record 17 of Set 7 | harrisonville
# Processing Record 18 of Set 7 | mar del plata
# Processing Record 19 of Set 7 | kieta
# Processing Record 20 of Set 7 | beira
# Processing Record 21 of Set 7 | radviliskis
# Processing Record 22 of Set 7 | tazovskiy
# Processing Record 23 of Set 7 | tigil
# Processing Record 24 of Set 7 | wad rawah
# Processing Record 25 of Set 7 | hokitika
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | elliot
# Processing Record 28 of Set 7 | comodoro rivadavia
# Processing Record 29 of Set 7 | anadyr
# Processing Record 30 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 7 | along
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | toamasina
# Processing Record 35 of Set 7 | soimus
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 7 | trapani
# Processing Record 39 of Set 7 | smithers
# Processing Record 40 of Set 7 | byron bay
# Processing Record 41 of Set 7 | castanos
# Processing Record 42 of Set 7 | boende
# Processing Record 43 of Set 7 | biak
# Processing Record 44 of Set 7 | parry sound
# Processing Record 45 of Set 7 | dubai
# Processing Record 46 of Set 7 | cuajinicuilapa
# Processing Record 47 of Set 7 | ancud
# Processing Record 48 of Set 7 | chicama
# Processing Record 49 of Set 7 | chapada dos guimaraes
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | mehamn
# Processing Record 2 of Set 8 | baykit
# Processing Record 3 of Set 8 | acajutla
# Processing Record 4 of Set 8 | kirakira
# Processing Record 5 of Set 8 | aden
# Processing Record 6 of Set 8 | touros
# Processing Record 7 of Set 8 | brainerd
# Processing Record 8 of Set 8 | aklavik
# Processing Record 9 of Set 8 | lauda-konigshofen
# Processing Record 10 of Set 8 | humboldt
# Processing Record 11 of Set 8 | berlevag
# Processing Record 12 of Set 8 | bima
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | huarmey
# Processing Record 15 of Set 8 | samarai
# Processing Record 16 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 8 | bonavista
# Processing Record 18 of Set 8 | turukhansk
# Processing Record 19 of Set 8 | pacific grove
# Processing Record 20 of Set 8 | siderno
# Processing Record 21 of Set 8 | cascais
# Processing Record 22 of Set 8 | narasannapeta
# Processing Record 23 of Set 8 | guerrero negro
# Processing Record 24 of Set 8 | altea
# Processing Record 25 of Set 8 | geraldton
# Processing Record 26 of Set 8 | anloga
# Processing Record 27 of Set 8 | northam
# Processing Record 28 of Set 8 | faanui
# Processing Record 29 of Set 8 | te anau
# Processing Record 30 of Set 8 | kahului
# Processing Record 31 of Set 8 | santiago
# Processing Record 32 of Set 8 | cap malheureux
# Processing Record 33 of Set 8 | dire
# Processing Record 34 of Set 8 | stephenville
# Processing Record 35 of Set 8 | kusk
# City not found. Skipping...
# Processing Record 36 of Set 8 | funadhoo
# Processing Record 37 of Set 8 | tortoli
# Processing Record 38 of Set 8 | njombe
# Processing Record 39 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 8 | gao
# Processing Record 41 of Set 8 | tagusao
# Processing Record 42 of Set 8 | torit
# Processing Record 43 of Set 8 | san policarpo
# Processing Record 44 of Set 8 | belaya gora
# Processing Record 45 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 8 | prince rupert
# Processing Record 47 of Set 8 | boueni
# Processing Record 48 of Set 8 | tura
# Processing Record 49 of Set 8 | sao filipe
# Processing Record 50 of Set 8 | tokmak
# Processing Record 1 of Set 9 | valley city
# Processing Record 2 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 9 | vostok
# Processing Record 4 of Set 9 | batagay
# Processing Record 5 of Set 9 | vestmanna
# Processing Record 6 of Set 9 | kaeo
# Processing Record 7 of Set 9 | walvis bay
# Processing Record 8 of Set 9 | lukovetskiy
# Processing Record 9 of Set 9 | cherskiy
# Processing Record 10 of Set 9 | vila franca do campo
# Processing Record 11 of Set 9 | kulhudhuffushi
# Processing Record 12 of Set 9 | gordeyevka
# Processing Record 13 of Set 9 | dalianwan
# Processing Record 14 of Set 9 | akureyri
# Processing Record 15 of Set 9 | banjarmasin
# Processing Record 16 of Set 9 | balezino
# Processing Record 17 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 9 | chulman
# Processing Record 19 of Set 9 | port augusta
# Processing Record 20 of Set 9 | corralillo
# Processing Record 21 of Set 9 | rio grande
# Processing Record 22 of Set 9 | mayo
# Processing Record 23 of Set 9 | iwanai
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | conceicao da barra
# Processing Record 26 of Set 9 | kjollefjord
# Processing Record 27 of Set 9 | gorontalo
# Processing Record 28 of Set 9 | bagdarin
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | kholodnyy
# Processing Record 31 of Set 9 | tilichiki
# Processing Record 32 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 9 | pula
# Processing Record 34 of Set 9 | egvekinot
# Processing Record 35 of Set 9 | muli
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | malanje
# Processing Record 38 of Set 9 | kiruna
# Processing Record 39 of Set 9 | nizhneivkino
# Processing Record 40 of Set 9 | careiro da varzea
# Processing Record 41 of Set 9 | irbeyskoye
# Processing Record 42 of Set 9 | college
# Processing Record 43 of Set 9 | biharkeresztes
# Processing Record 44 of Set 9 | fortuna foothills
# Processing Record 45 of Set 9 | panama city
# Processing Record 46 of Set 9 | hauterive
# Processing Record 47 of Set 9 | skowhegan
# Processing Record 48 of Set 9 | ostrovnoy
# Processing Record 49 of Set 9 | lorengau
# Processing Record 50 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 10 | nongpoh
# Processing Record 2 of Set 10 | lyngseidet
# Processing Record 3 of Set 10 | itoman
# Processing Record 4 of Set 10 | chumikan
# Processing Record 5 of Set 10 | ayna
# Processing Record 6 of Set 10 | bauchi
# Processing Record 7 of Set 10 | suluq
# Processing Record 8 of Set 10 | sharjah
# Processing Record 9 of Set 10 | magole
# Processing Record 10 of Set 10 | colac
# Processing Record 11 of Set 10 | san rafael
# Processing Record 12 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 13 of Set 10 | srednekolymsk
# Processing Record 14 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 10 | camargo
# Processing Record 16 of Set 10 | hirara
# Processing Record 17 of Set 10 | roebourne
# Processing Record 18 of Set 10 | kathmandu
# Processing Record 19 of Set 10 | san patricio
# Processing Record 20 of Set 10 | abu kamal
# Processing Record 21 of Set 10 | alyangula
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | kolyvan
# Processing Record 24 of Set 10 | santa cruz
# Processing Record 25 of Set 10 | verkhnyaya inta
# Processing Record 26 of Set 10 | durango
# Processing Record 27 of Set 10 | turan
# Processing Record 28 of Set 10 | dezful
# Processing Record 29 of Set 10 | leningradskiy
# Processing Record 30 of Set 10 | parvatipuram
# Processing Record 31 of Set 10 | pilar
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | lokomotivnyy
# Processing Record 34 of Set 10 | octeville
# Processing Record 35 of Set 10 | taldan
# Processing Record 36 of Set 10 | arandis
# Processing Record 37 of Set 10 | inhambane
# Processing Record 38 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 10 | vallenar
# Processing Record 40 of Set 10 | lucera
# Processing Record 41 of Set 10 | luderitz
# Processing Record 42 of Set 10 | thano bula khan
# City not found. Skipping...
# Processing Record 43 of Set 10 | bend
# Processing Record 44 of Set 10 | manado
# Processing Record 45 of Set 10 | tarbagatay
# Processing Record 46 of Set 10 | coihaique
# Processing Record 47 of Set 10 | omboue
# Processing Record 48 of Set 10 | campos belos
# Processing Record 49 of Set 10 | ixtapa
# Processing Record 50 of Set 10 | ormara
# Processing Record 1 of Set 11 | knysna
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | nenjiang
# Processing Record 4 of Set 11 | pen
# Processing Record 5 of Set 11 | jacareacanga
# Processing Record 6 of Set 11 | macusani
# Processing Record 7 of Set 11 | leh
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | saint-augustin
# Processing Record 10 of Set 11 | puerto madryn
# Processing Record 11 of Set 11 | fairbanks
# Processing Record 12 of Set 11 | shangqiu
# Processing Record 13 of Set 11 | afanasyevo
# City not found. Skipping...
# Processing Record 14 of Set 11 | canyon
# Processing Record 15 of Set 11 | kamenka
# Processing Record 16 of Set 11 | jalu
# Processing Record 17 of Set 11 | ust-maya
# Processing Record 18 of Set 11 | paramonga
# Processing Record 19 of Set 11 | camocim
# Processing Record 20 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 11 | nioro
# Processing Record 22 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 11 | guican
# Processing Record 24 of Set 11 | sorland
# Processing Record 25 of Set 11 | monze
# Processing Record 26 of Set 11 | ca mau
# Processing Record 27 of Set 11 | port hawkesbury
# Processing Record 28 of Set 11 | razdolinsk
# Processing Record 29 of Set 11 | el dorado
# Processing Record 30 of Set 11 | yar-sale
# Processing Record 31 of Set 11 | pemba
# Processing Record 32 of Set 11 | trojes
# Processing Record 33 of Set 11 | riachao das neves
# Processing Record 34 of Set 11 | pontes e lacerda
# Processing Record 35 of Set 11 | aksarka
# Processing Record 36 of Set 11 | lasa
# Processing Record 37 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 38 of Set 11 | matara
# Processing Record 39 of Set 11 | saint george
# Processing Record 40 of Set 11 | rocha
# Processing Record 41 of Set 11 | mallama
# City not found. Skipping...
# Processing Record 42 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 11 | puksoozero
# Processing Record 44 of Set 11 | araouane
# Processing Record 45 of Set 11 | noumea
# Processing Record 46 of Set 11 | dharchula
# Processing Record 47 of Set 11 | vredendal
# Processing Record 48 of Set 11 | safford
# Processing Record 49 of Set 11 | menongue
# Processing Record 50 of Set 11 | kalaleh
# Processing Record 1 of Set 12 | isangel
# Processing Record 2 of Set 12 | armidale
# Processing Record 3 of Set 12 | catamarca
# Processing Record 4 of Set 12 | sechura
# Processing Record 5 of Set 12 | pinahat
# Processing Record 6 of Set 12 | port blair
# Processing Record 7 of Set 12 | nicoya
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | passagem franca
# Processing Record 10 of Set 12 | bac lieu
# Processing Record 11 of Set 12 | waingapu
# Processing Record 12 of Set 12 | ullapool
# Processing Record 13 of Set 12 | bathsheba
# Processing Record 14 of Set 12 | opuwo
# Processing Record 15 of Set 12 | gobabis
# Processing Record 16 of Set 12 | olafsvik
# Processing Record 17 of Set 12 | agva
# City not found. Skipping...
# Processing Record 18 of Set 12 | gravdal
# Processing Record 19 of Set 12 | buala
# Processing Record 20 of Set 12 | nizwa
# Processing Record 21 of Set 12 | doka
# Processing Record 22 of Set 12 | adre
# Processing Record 23 of Set 12 | vardo
# Processing Record 24 of Set 12 | dandong
# Processing Record 25 of Set 12 | fare
# Processing Record 26 of Set 12 | salihorsk
# Processing Record 27 of Set 12 | sobolevo
# Processing Record 28 of Set 12 | dibrugarh
# Processing Record 29 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 30 of Set 12 | jardim
# Processing Record 31 of Set 12 | yamada
# Processing Record 32 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 33 of Set 12 | goderich
# Processing Record 34 of Set 12 | namatanai
# Processing Record 35 of Set 12 | plettenberg bay
# Processing Record 36 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 12 | hoopstad
# Processing Record 38 of Set 12 | peruibe
# Processing Record 39 of Set 12 | nabire
# Processing Record 40 of Set 12 | bentiu
# Processing Record 41 of Set 12 | naryan-mar
# Processing Record 42 of Set 12 | kachug
# Processing Record 43 of Set 12 | port shepstone
# Processing Record 44 of Set 12 | gasa
# Processing Record 45 of Set 12 | aitape
# Processing Record 46 of Set 12 | bondowoso
# Processing Record 47 of Set 12 | okha
# Processing Record 48 of Set 12 | andenes
# Processing Record 49 of Set 12 | atasu
# Processing Record 50 of Set 12 | meulaboh
# Processing Record 1 of Set 13 | sao jose da coroa grande
# Processing Record 2 of Set 13 | stornoway
# Processing Record 3 of Set 13 | qujing
# Processing Record 4 of Set 13 | luau
# Processing Record 5 of Set 13 | ratnagiri
# Processing Record 6 of Set 13 | el escorial
# Processing Record 7 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 13 | rauma
# Processing Record 9 of Set 13 | warka
# Processing Record 10 of Set 13 | portland
# Processing Record 11 of Set 13 | coffs harbour
# Processing Record 12 of Set 13 | salamiyah
# Processing Record 13 of Set 13 | berdigestyakh
# Processing Record 14 of Set 13 | dingle
# Processing Record 15 of Set 13 | letka
# Processing Record 16 of Set 13 | ballater
# Processing Record 17 of Set 13 | llanes
# Processing Record 18 of Set 13 | kedrovyy
# Processing Record 19 of Set 13 | garmsar
# Processing Record 20 of Set 13 | lukulu
# Processing Record 21 of Set 13 | malacky
# Processing Record 22 of Set 13 | vila
# Processing Record 23 of Set 13 | nigde
# Processing Record 24 of Set 13 | richards bay
# Processing Record 25 of Set 13 | ganzhou
# Processing Record 26 of Set 13 | coos bay
# Processing Record 27 of Set 13 | port-cartier
# Processing Record 28 of Set 13 | colares
# Processing Record 29 of Set 13 | kosh-agach
# Processing Record 30 of Set 13 | maumere
# Processing Record 31 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 32 of Set 13 | urumqi
# Processing Record 33 of Set 13 | san cristobal
# Processing Record 34 of Set 13 | alberton
# Processing Record 35 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 13 | tomatlan
# Processing Record 37 of Set 13 | kasongo
# Processing Record 38 of Set 13 | sakakah
# Processing Record 39 of Set 13 | kudahuvadhoo
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | kyren
# Processing Record 42 of Set 13 | khromtau
# Processing Record 43 of Set 13 | salalah
# Processing Record 44 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 13 | znamenskoye
# Processing Record 46 of Set 13 | progreso
# Processing Record 47 of Set 13 | coracora
# Processing Record 48 of Set 13 | tocopilla
# Processing Record 49 of Set 13 | orahovac
# Processing Record 50 of Set 13 | longyearbyen
# Processing Record 1 of Set 14 | quatre cocos
# Processing Record 2 of Set 14 | zhezkazgan
# Processing Record 3 of Set 14 | obregon
# Processing Record 4 of Set 14 | moa
# Processing Record 5 of Set 14 | santa rosalia
# Processing Record 6 of Set 14 | zelenets
# Processing Record 7 of Set 14 | jizan
# Processing Record 8 of Set 14 | castlebar
# Processing Record 9 of Set 14 | banyo
# Processing Record 10 of Set 14 | kishorganj
# Processing Record 11 of Set 14 | linxia
# Processing Record 12 of Set 14 | liverpool
# Processing Record 13 of Set 14 | tshela
# Processing Record 14 of Set 14 | aksu
# Processing Record 15 of Set 14 | huercal-overa
# Processing Record 16 of Set 14 | mindelo
# Processing Record 17 of Set 14 | akyab
# Processing Record 18 of Set 14 | mondlo
# Processing Record 19 of Set 14 | dubbo
# Processing Record 20 of Set 14 | nurota
# Processing Record 21 of Set 14 | pemangkat
# Processing Record 22 of Set 14 | karlstad
# Processing Record 23 of Set 14 | veraval
# Processing Record 24 of Set 14 | strezhevoy
# Processing Record 25 of Set 14 | blagoyevo
# Processing Record 26 of Set 14 | saint-pierre
# Processing Record 27 of Set 14 | kismayo
# Processing Record 28 of Set 14 | nipawin
# Processing Record 29 of Set 14 | leshukonskoye
# Processing Record 30 of Set 14 | camacha
# Processing Record 31 of Set 14 | catalina
# Processing Record 32 of Set 14 | ibra
# Processing Record 33 of Set 14 | shepsi
# Processing Record 34 of Set 14 | tateyama
# Processing Record 35 of Set 14 | rajapur
# Processing Record 36 of Set 14 | aksarayskiy
# Processing Record 37 of Set 14 | sao felix do xingu
# Processing Record 38 of Set 14 | garza garcia
# Processing Record 39 of Set 14 | bardiyah
# Processing Record 40 of Set 14 | sibolga
# Processing Record 41 of Set 14 | wajir
# Processing Record 42 of Set 14 | mahanoro
# Processing Record 43 of Set 14 | alice springs
# Processing Record 44 of Set 14 | itaituba
# Processing Record 45 of Set 14 | inongo
# Processing Record 46 of Set 14 | raga
# Processing Record 47 of Set 14 | floresta
# Processing Record 48 of Set 14 | rassvet
# Processing Record 49 of Set 14 | balykshi
# Processing Record 50 of Set 14 | kangaatsiaq
# Processing Record 1 of Set 15 | evanston
# Processing Record 2 of Set 15 | huntsville
# Processing Record 3 of Set 15 | honiara
# Processing Record 4 of Set 15 | homer
# Processing Record 5 of Set 15 | neiafu
# Processing Record 6 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 15 | volchikha
# Processing Record 8 of Set 15 | novikovo
# Processing Record 9 of Set 15 | de-kastri
# Processing Record 10 of Set 15 | guthrie
# Processing Record 11 of Set 15 | sovetskiy
# Processing Record 12 of Set 15 | kefamenanu
# Processing Record 13 of Set 15 | padang
# Processing Record 14 of Set 15 | sakaiminato
# Processing Record 15 of Set 15 | nago
# Processing Record 16 of Set 15 | kirksville
# Processing Record 17 of Set 15 | arkhangelsk
# Processing Record 18 of Set 15 | remanso
# Processing Record 19 of Set 15 | daru
# Processing Record 20 of Set 15 | payo
# Processing Record 21 of Set 15 | tarko-sale
# Processing Record 22 of Set 15 | yaan
# Processing Record 23 of Set 15 | fershampenuaz
# Processing Record 24 of Set 15 | sangmelima
# Processing Record 25 of Set 15 | severnyy-kospashskiy
# Processing Record 26 of Set 15 | xichang
# Processing Record 27 of Set 15 | emerald
# Processing Record 28 of Set 15 | viedma
# Processing Record 29 of Set 15 | xining
# Processing Record 30 of Set 15 | praia da vitoria
# Processing Record 31 of Set 15 | rumoi
# Processing Record 32 of Set 15 | casa nova
# Processing Record 33 of Set 15 | kuala krai
# City not found. Skipping...
# Processing Record 34 of Set 15 | chegutu
# Processing Record 35 of Set 15 | aykhal
# Processing Record 36 of Set 15 | alta floresta
# Processing Record 37 of Set 15 | north battleford
# Processing Record 38 of Set 15 | basco
# Processing Record 39 of Set 15 | talara
# Processing Record 40 of Set 15 | bhuj
# Processing Record 41 of Set 15 | coahuayana
# Processing Record 42 of Set 15 | saryagash
# Processing Record 43 of Set 15 | sao miguel do araguaia
# Processing Record 44 of Set 15 | umm kaddadah
# Processing Record 45 of Set 15 | yumen
# Processing Record 46 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 15 | waipawa
# Processing Record 48 of Set 15 | nchelenge
# Processing Record 49 of Set 15 | tacna
# Processing Record 50 of Set 15 | hailar
# Processing Record 1 of Set 16 | neuquen
# Processing Record 2 of Set 16 | kralendijk
# Processing Record 3 of Set 16 | athabasca
# Processing Record 4 of Set 16 | valdivia
# Processing Record 5 of Set 16 | mokhsogollokh
# Processing Record 6 of Set 16 | priargunsk
# Processing Record 7 of Set 16 | venice
# Processing Record 8 of Set 16 | hambantota
# Processing Record 9 of Set 16 | borskoye
# Processing Record 10 of Set 16 | kavieng
# Processing Record 11 of Set 16 | akdagmadeni
# Processing Record 12 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 16 | shu
# Processing Record 14 of Set 16 | pychas
# Processing Record 15 of Set 16 | haines junction
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Carnarvon -24.8667  113.6333     73.40        71          74       24.23
# 1       Hobart -42.8794  147.3294     45.00        93          75        6.91
# 2      Ushuaia -54.8000  -68.3000     51.80        40          20       12.66
# 3     Linhares -19.3911  -40.0722     76.55        70          37        4.56
# 4      Ballina -28.8667  153.5667     55.40        82          90        6.91
# 5       Nassau  40.7507  -73.5829     50.00        83         100        3.00
# 6       Broome  42.2506  -75.8330     46.99       100          90        9.22
# 7         Faya  18.3851   42.4509     64.40        63           0        4.61
# 8       Yulara -25.2406  130.9889     60.80        41          96        4.61
# 9  Provideniya  64.3833 -173.3000     17.92        88         100       16.35
#
#   Country Current Description                 Date
# 0      AU       broken clouds  2021-04-12 20:50:28
# 1      AU       broken clouds  2021-04-12 20:48:39
# 2      AR          few clouds  2021-04-12 20:48:43
# 3      BR    scattered clouds  2021-04-12 20:57:33
# 4      AU     overcast clouds  2021-04-12 20:57:33
# 5      US          light rain  2021-04-12 20:56:20
# 6      US     overcast clouds  2021-04-12 20:57:34
# 7      SA           clear sky  2021-04-12 20:57:34
# 8      AU     overcast clouds  2021-04-12 20:52:00
# 9      RU     overcast clouds  2021-04-12 20:57:35

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Carnarvon      AU -24.8667  113.6333     73.40        71          74
# 1     Hobart      AU -42.8794  147.3294     45.00        93          75
# 2    Ushuaia      AR -54.8000  -68.3000     51.80        40          20
# 3   Linhares      BR -19.3911  -40.0722     76.55        70          37
# 4    Ballina      AU -28.8667  153.5667     55.40        82          90
#
#    Wind Speed Current Description
# 0       24.23       broken clouds
# 1        6.91       broken clouds
# 2       12.66          few clouds
# 3        4.56    scattered clouds
# 4        6.91     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
